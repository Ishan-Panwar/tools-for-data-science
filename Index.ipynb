# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Ishan Panwar</b>
# College student

# %% [markdown]
# <i>I am interested in data science because I eventually want to work in the field of aerospace and it would give me a headstart in the field</i>

# %% [markdown]
# ### My code is going to print "Hello world"

# %%
printf("Hello world")

# %% [markdown]
# <ol>
#     <li>3 kg onions</li>
#     <li>4 gm butter</li>
# </ol>
# <hr>
# <ul>
#     <li>onions</li>
#     <li>butter</li>
# </ul>
